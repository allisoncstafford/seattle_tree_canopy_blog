# %% [markdown]
# # Seattle Tree Canopy Blog

# %% [markdown]
# Data Sources:
#  * http://data-seattlecitygis.opendata.arcgis.com/datasets/tree-canopy-2016
#  * http://data-seattlecitygis.opendata.arcgis.com/datasets/trees

# %%
#  import necessary packages
import pandas as pd
import geopandas as gpd

# %%
# import tree canopy data
canopy = gpd.read_file('../data/tree_canopy_2016/Tree_Canopy_2016.shp')

# %%
canopy.plot()
# Out:
# <AxesSubplot:>

# %%
canopy.head().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Relative rates compared to building zone

# %% [markdown]
# ## Relative to ethnic diversity

# %% [markdown]
# ## Compared to walkability

# %% [markdown]
# ## Income of Neighborhood

# %% [markdown]
# ## Temperature

# %% [markdown]
# ## Air Quality

# %% [markdown]
# ## Rainfall
